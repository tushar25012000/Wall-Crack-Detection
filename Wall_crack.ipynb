# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="KUrxMO8mMazEfdWffDek")
project = rf.workspace("core-labeling").project("crack-detection-gpbys")
dataset = project.version(2).download("yolov8")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 68.5/68.5 kB 2.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.3/158.3 kB 7.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 8.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 8.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 18.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 10.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.5/77.5 kB 12.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 9.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.1
#     Uninstalling pyparsing-3.1.1:
#       Successfully uninstalled pyparsing-3.1.1
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.8.1.78
# ...

# %%
# List the contents of the crack_detection folder
# !ls /content/crack-detection-2
# Out:
# data.yaml  README.dataset.txt  README.roboflow.txt  test  train  valid

# %%
# Display the contents of the data.yaml file
# !cat /content/crack-detection-2/data.yaml
# Out:
# names:
# - Crack
# nc: 1
# roboflow:
#   license: Public Domain
#   project: crack-detection-gpbys
#   url: https://universe.roboflow.com/core-labeling/crack-detection-gpbys/dataset/2
#   version: 2
#   workspace: core-labeling
# test: ../test/images
# train: crack-detection-2/train/images
# val: crack-detection-2/valid/images

# %% [markdown]
# YOLOv8 for wall crack detection

# %%
pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 660.5/660.5 kB 5.2 MB/s eta 0:00:00
# ...

# %%
#YOLOv8

# %%
from ultralytics import YOLO
import os
from IPython.display import display,Image
from IPython import display
display.clear_output()
# !yolo mode=checks
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/cfg/__init__.py", line 395, in entrypoint
#     raise ValueError(f"Invalid 'mode={mode}'. Valid modes are {MODES}.\n{CLI_HELP_MSG}")
# ValueError: Invalid 'mode=<module 'ultralytics.utils.checks' from '/usr/local/lib/python3.10/dist-packages/ultralytics/utils/checks.py'>'. Valid modes are ('train', 'val', 'predict', 'export', 'track', 'benchmark').
#
#     Arguments received: ['yolo', 'mode=checks']. Ultralytics 'yolo' commands use the following syntax:
#
#         yolo TASK MODE ARGS
#
#         Where   TASK (optional) is one of ('detect', 'segment', 'classify', 'pose')
#                 MODE (required) is one of ('train', 'val', 'predict', 'export', 'track', 'benchmark')
#                 ARGS (optional) are any number of custom 'arg=value' pairs like 'imgsz=320' that override defaults.
# ...

# %%
from ultralytics import YOLO

# %%
from ultralytics import YOLO

# Create a new YOLO model from scratch
model = YOLO('yolov8n.yaml')

# Load a pretrained YOLO model (recommended for training)
model = YOLO('yolov8n.pt')

# Train the model using the  dataset for 3 epochs
results = model.train(data='/content/crack-detection-2/data.yaml', epochs=9)

# Evaluate the model's performance on the validation set
results = model.val()

# # Perform object detection on an image using the model
# results = model('https://ultralytics.com/images/bus.jpg')

# # Export the model to ONNX format
# success = model.export(format='onnx')
# Out:
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
# ...

# %%
# Evaluate the model's performance on the validation set
results = model.val()
# Out:
# Ultralytics YOLOv8.0.227 🚀 Python-3.10.12 torch-2.1.0+cu121 CUDA:0 (Tesla T4, 15102MiB)
# val: Scanning /content/crack-detection-2/valid/labels.cache... 548 images, 25 backgrounds, 0 corrupt: 100%|██████████| 548/548 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 35/35 [00:09<00:00,  3.63it/s]
#                    all        548        702      0.665      0.598      0.627      0.318
# Speed: 0.4ms preprocess, 4.7ms inference, 0.0ms loss, 2.2ms postprocess per image
# Results saved to runs/detect/train33

# %%
Image(filename="/content/runs/detect/train32/confusion_matrix.png", width=800)

# %%
Image(filename="/content/runs/detect/train32/val_batch2_pred.jpg", width=800)

# %%
Image(filename="/content/runs/detect/train32/val_batch2_labels.jpg", width=800)

# %%
Image(filename="/content/runs/detect/train32/val_batch0_pred.jpg", width=800)

# %%
Image(filename="/content/runs/detect/train32/confusion_matrix_normalized.png", width=800)

# %%
Image(filename="/content/runs/detect/train32/F1_curve.png", width=800)

# %%
Image(filename="/content/runs/detect/train32/PR_curve.png", width=800)

# %%
Image(filename="/content/runs/detect/train32/P_curve.png", width=800)

# %%
Image(filename="/content/runs/detect/train32/R_curve.png", width=800)
